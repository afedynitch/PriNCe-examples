# %%
# Point PriNCe at the FLUKA-derived photo-nuclear database (v1).
# Built by prince-fluka-utils — replaces the SOPHIA + PEANUT/TALYS
# split. The path below is the production v1 build on SATORI; override
# config.fluka_db_path / config.fluka_db_fname for a different machine.
import prince_cr.config
prince_cr.config.fluka_db_path = '/ceph/work/SATORI/anatoli/devel/prince-fluka-utils/'
prince_cr.config.fluka_db_fname = 'prince_db_v2-sparse.h5'
prince_cr.config.max_mass = 56

# %%
import os
import numpy as np
import scipy as sc
import matplotlib.pyplot as plt
import matplotlib as mpl
import pickle as pickle

# %%
import prince_cr.config
from prince_cr import core, util, photonfields, cross_sections
from prince_cr import util as pru
# Out:
# /ceph/work/SATORI/anatoli/devel/PriNCe/src/prince_cr/data.py:559: RuntimeWarning: FLUKA decay db has empty channels for 116 unstable nuclei (SPDCEV / sampling failures). Falling back to β-direction heuristic per-mother — this is a FUDGE; verify the chain reducer doesn't hit cycle warnings downstream and fix at the next prince-fluka-utils rebuild:
#   PDG=1000010060  A=6 Z=1  half_life=2.851e-22s  → heuristic daughter PDG=1000020060
#   PDG=1000030050  A=5 Z=3  half_life=3.709e-22s  → heuristic daughter PDG=1000020050
#   PDG=1000020050  A=5 Z=2  half_life=7.041e-22s  → heuristic daughter PDG=1000030050
#   PDG=1000100160  A=16 Z=10  half_life=3.740e-21s  → heuristic daughter PDG=1000090160
#   PDG=1000070240  A=24 Z=7  half_life=5.200e-08s  → heuristic daughter PDG=1000080240
#   PDG=1000842240  A=224 Z=84  half_life=3.000e-07s  → heuristic daughter PDG=1000852240
#   PDG=1000771650  A=165 Z=77  half_life=1.000e-06s  → heuristic daughter PDG=1000781650
#   PDG=1000691450  A=145 Z=69  half_life=3.170e-06s  → heuristic daughter PDG=1000701450
#   PDG=1001012450  A=245 Z=101  half_life=9.000e-04s  → heuristic daughter PDG=1001022450
#   PDG=1000731550  A=155 Z=73  half_life=2.900e-03s  → heuristic daughter PDG=1000741550
#   PDG=1001002440  A=244 Z=100  half_life=3.300e-03s  → heuristic daughter PDG=1001012440
#   PDG=1000170500  A=50 Z=17  half_life=5.000e-03s  → heuristic daughter PDG=1000180500
#   PDG=1000050170  A=17 Z=5  half_life=5.080e-03s  → heuristic daughter PDG=1000060170
#   PDG=1000811760  A=176 Z=81  half_life=5.200e-03s  → heuristic daughter PDG=1000821760
#   PDG=1000831840  A=184 Z=83  half_life=6.600e-03s  → heuristic daughter PDG=1000841840
#   PDG=1000210590  A=59 Z=21  half_life=7.100e-03s  → heuristic daughter PDG=1000220590
#   PDG=1000100300  A=30 Z=10  half_life=7.300e-03s  → heuristic daughter PDG=1000110300
#   PDG=1000280490  A=49 Z=28  half_life=7.500e-03s  → heuristic daughter PDG=1000270490
#   PDG=1000801760  A=176 Z=80  half_life=2.030e-02s  → heuristic daughter PDG=1000811760
#   PDG=1000240680  A=68 Z=24  half_life=2.600e-02s  → heuristic daughter PDG=1000250680
#   PDG=1000250680  A=68 Z=25  half_life=2.840e-02s  → heuristic daughter PDG=1000260680
#   PDG=1000421160  A=116 Z=42  half_life=3.200e-02s  → heuristic daughter PDG=1000431160
#   PDG=1000381050  A=105 Z=38  half_life=3.900e-02s  → heuristic daughter PDG=1000391050
#   PDG=1000110300  A=30 Z=11  half_life=4.800e-02s  → heuristic daughter PDG=1000120300
#   PDG=1000461260  A=126 Z=46  half_life=4.860e-02s  → heuristic daughter PDG=1000471260
#   PDG=1000471260  A=126 Z=47  half_life=5.200e-02s  → heuristic daughter PDG=1000481260
#   PDG=1000431160  A=116 Z=43  half_life=5.700e-02s  → heuristic daughter PDG=1000441160
#   PDG=1000481330  A=133 Z=48  half_life=5.700e-02s  → heuristic daughter PDG=1000491330
#   PDG=1000220590  A=59 Z=22  half_life=5.800e-02s  → heuristic daughter PDG=1000230590
#   PDG=1000260490  A=49 Z=26  half_life=6.470e-02s  → heuristic daughter PDG=1000250490
#   PDG=1000080240  A=24 Z=8  half_life=6.500e-02s  → heuristic daughter PDG=1000090240
#   PDG=1000711550  A=155 Z=71  half_life=6.800e-02s  → heuristic daughter PDG=1000721550
#   PDG=1000761650  A=165 Z=76  half_life=7.100e-02s  → heuristic daughter PDG=1000771650
#   PDG=1000230590  A=59 Z=23  half_life=7.500e-02s  → heuristic daughter PDG=1000240590
#   PDG=1000391050  A=105 Z=39  half_life=9.500e-02s  → heuristic daughter PDG=1000401050
#   PDG=1000781720  A=172 Z=78  half_life=9.760e-02s  → heuristic daughter PDG=1000791720
#   PDG=1000631320  A=132 Z=63  half_life=1.000e-01s  → heuristic daughter PDG=1000641320
#   PDG=1000180500  A=50 Z=18  half_life=1.060e-01s  → heuristic daughter PDG=1000190500
#   PDG=1000381010  A=101 Z=38  half_life=1.130e-01s  → heuristic daughter PDG=1000391010
#   PDG=1000591590  A=159 Z=59  half_life=1.300e-01s  → heuristic daughter PDG=1000601590
#   PDG=1000340670  A=67 Z=34  half_life=1.360e-01s  → heuristic daughter PDG=1000330670
#   PDG=1000541460  A=146 Z=54  half_life=1.460e-01s  → heuristic daughter PDG=1000551460
#   PDG=1000491330  A=133 Z=49  half_life=1.650e-01s  → heuristic daughter PDG=1000501330
#   PDG=1000260680  A=68 Z=26  half_life=1.880e-01s  → heuristic daughter PDG=1000270680
#   PDG=1000060170  A=17 Z=6  half_life=1.930e-01s  → heuristic daughter PDG=1000070170
#   PDG=1000441160  A=116 Z=44  half_life=2.040e-01s  → heuristic daughter PDG=1000451160
#   PDG=1000581560  A=156 Z=58  half_life=2.330e-01s  → heuristic daughter PDG=1000591560
#   PDG=1000431120  A=112 Z=43  half_life=2.710e-01s  → heuristic daughter PDG=1000441120
#   PDG=1000250630  A=63 Z=25  half_life=2.750e-01s  → heuristic daughter PDG=1000260630
#   PDG=1000832240  A=224 Z=83  half_life=3.000e-01s  → heuristic daughter PDG=1000842240
#   PDG=1000551460  A=146 Z=55  half_life=3.220e-01s  → heuristic daughter PDG=1000561460
#   PDG=1000120300  A=30 Z=12  half_life=3.350e-01s  → heuristic daughter PDG=1000130300
#   PDG=1000851970  A=197 Z=85  half_life=3.880e-01s  → heuristic daughter PDG=1000861970
#   PDG=1000090240  A=24 Z=9  half_life=3.900e-01s  → heuristic daughter PDG=1000100240
#   PDG=1000591560  A=156 Z=59  half_life=4.440e-01s  → heuristic daughter PDG=1000601560
#   PDG=1000561150  A=115 Z=56  half_life=4.500e-01s  → heuristic daughter PDG=1000571150
#   PDG=1000240590  A=59 Z=24  half_life=4.600e-01s  → heuristic daughter PDG=1000250590
#   PDG=1000190500  A=50 Z=19  half_life=4.720e-01s  → heuristic daughter PDG=1000200500
#   PDG=1000601590  A=159 Z=60  half_life=4.850e-01s  → heuristic daughter PDG=1000611590
#   PDG=1000821840  A=184 Z=82  half_life=4.900e-01s  → heuristic daughter PDG=1000831840
#   PDG=1000481260  A=126 Z=48  half_life=5.150e-01s  → heuristic daughter PDG=1000491260
#   PDG=1000401050  A=105 Z=40  half_life=6.700e-01s  → heuristic daughter PDG=1000411050
#   PDG=1000721550  A=155 Z=72  half_life=8.900e-01s  → heuristic daughter PDG=1000731550
#   PDG=1000461190  A=119 Z=46  half_life=9.200e-01s  → heuristic daughter PDG=1000471190
#   PDG=1000791760  A=176 Z=79  half_life=1.050e+00s  → heuristic daughter PDG=1000801760
#   PDG=1000942280  A=228 Z=94  half_life=1.100e+00s  → heuristic daughter PDG=1000952280
#   PDG=1000310810  A=81 Z=31  half_life=1.217e+00s  → heuristic daughter PDG=1000320810
#   PDG=1000551150  A=115 Z=55  half_life=1.400e+00s  → heuristic daughter PDG=1000561150
#   PDG=1000611590  A=159 Z=61  half_life=1.480e+00s  → heuristic daughter PDG=1000621590
#   PDG=1000751650  A=165 Z=75  half_life=1.600e+00s  → heuristic daughter PDG=1000761650
#   PDG=1000631660  A=166 Z=63  half_life=1.700e+00s  → heuristic daughter PDG=1000641660
#   PDG=1000441120  A=112 Z=44  half_life=1.750e+00s  → heuristic daughter PDG=1000451120
#   PDG=1000701550  A=155 Z=70  half_life=1.793e+00s  → heuristic daughter PDG=1000711550
#   PDG=1000561460  A=146 Z=56  half_life=2.210e+00s  → heuristic daughter PDG=1000571460
#   PDG=1000852290  A=229 Z=85  half_life=2.900e+00s  → heuristic daughter PDG=1000862290
#   PDG=1000411050  A=105 Z=41  half_life=2.950e+00s  → heuristic daughter PDG=1000421050
#   PDG=1000451120  A=112 Z=45  half_life=3.600e+00s  → heuristic daughter PDG=1000461120
#   PDG=1000621320  A=132 Z=62  half_life=4.000e+00s  → heuristic daughter PDG=1000631320
#   PDG=1000070170  A=17 Z=7  half_life=4.173e+00s  → heuristic daughter PDG=1000080170
#   PDG=1000771720  A=172 Z=77  half_life=4.400e+00s  → heuristic daughter PDG=1000781720
#   PDG=1000641660  A=166 Z=64  half_life=4.800e+00s  → heuristic daughter PDG=1000651660
#   PDG=1000741650  A=165 Z=74  half_life=5.100e+00s  → heuristic daughter PDG=1000751650
#   PDG=1000601560  A=156 Z=60  half_life=5.260e+00s  → heuristic daughter PDG=1000611560
#   PDG=1000711850  A=185 Z=71  half_life=5.600e+00s  → heuristic daughter PDG=1000721850
#   PDG=1000471190  A=119 Z=47  half_life=6.000e+00s  → heuristic daughter PDG=1000481190
#   PDG=1000260630  A=63 Z=26  half_life=6.100e+00s  → heuristic daughter PDG=1000270630
#   PDG=1000781760  A=176 Z=78  half_life=6.330e+00s  → heuristic daughter PDG=1000791760
#   PDG=1000681770  A=177 Z=68  half_life=8.500e+00s  → heuristic daughter PDG=1000691770
#   PDG=1000771760  A=176 Z=77  half_life=8.700e+00s  → heuristic daughter PDG=1000781760
#   PDG=1000811840  A=184 Z=81  half_life=1.010e+01s  → heuristic daughter PDG=1000821840
#   PDG=1000862290  A=229 Z=86  half_life=1.200e+01s  → heuristic daughter PDG=1000872290
#   PDG=1000872060  A=206 Z=87  half_life=1.600e+01s  → heuristic daughter PDG=1000882060
#   PDG=1000541150  A=115 Z=54  half_life=1.800e+01s  → heuristic daughter PDG=1000551150
#   PDG=1000691550  A=155 Z=69  half_life=2.160e+01s  → heuristic daughter PDG=1000701550
#   PDG=1000882340  A=234 Z=88  half_life=3.000e+01s  → heuristic daughter PDG=1000892340
#   PDG=1000801840  A=184 Z=80  half_life=3.087e+01s  → heuristic daughter PDG=1000811840
#   PDG=1000992440  A=244 Z=99  half_life=3.700e+01s  → heuristic daughter PDG=1001002440
#   PDG=1000892340  A=234 Z=89  half_life=4.400e+01s  → heuristic daughter PDG=1000902340
#   PDG=1000872290  A=229 Z=87  half_life=5.020e+01s  → heuristic daughter PDG=1000882290
#   PDG=1000531150  A=115 Z=53  half_life=7.800e+01s  → heuristic daughter PDG=1000541150
#   PDG=1000852240  A=224 Z=85  half_life=7.800e+01s  → heuristic daughter PDG=1000862240
#   PDG=1000841970  A=197 Z=84  half_life=8.400e+01s  → heuristic daughter PDG=1000851970
#   PDG=1000691770  A=177 Z=69  half_life=9.000e+01s  → heuristic daughter PDG=1000701770
#   PDG=1000932450  A=245 Z=93  half_life=1.200e+02s  → heuristic daughter PDG=1000942450
#   PDG=1000721850  A=185 Z=72  half_life=2.100e+02s  → heuristic daughter PDG=1000731850
#   PDG=1000761760  A=176 Z=76  half_life=2.160e+02s  → heuristic daughter PDG=1000771760
#   PDG=1000882290  A=229 Z=88  half_life=2.400e+02s  → heuristic daughter PDG=1000892290
#   PDG=1000671690  A=169 Z=67  half_life=2.832e+02s  → heuristic daughter PDG=1000681690
#   PDG=1000681550  A=155 Z=68  half_life=3.180e+02s  → heuristic daughter PDG=1000691550
#   PDG=1000831970  A=197 Z=83  half_life=5.598e+02s  → heuristic daughter PDG=1000841970
#   PDG=1000982440  A=244 Z=98  half_life=1.164e+03s  → heuristic daughter PDG=1000992440
#   PDG=1000862240  A=224 Z=86  half_life=6.420e+03s  → heuristic daughter PDG=1000872240
#   PDG=1000912390  A=239 Z=91  half_life=6.480e+03s  → heuristic daughter PDG=1000922390
#   PDG=1000972440  A=244 Z=97  half_life=1.566e+04s  → heuristic daughter PDG=1000982440
#   PDG=1000782020  A=202 Z=78  half_life=1.584e+05s  → heuristic daughter PDG=1000792020
#   PDG=1000010030  A=3 Z=1  half_life=3.888e+08s  → heuristic daughter PDG=1000020030
#   _merge_tabulated_decays(spec_data)

# %% [markdown]
# # General Information

# %% [markdown]
# This Notebook contains reproductions of results from arXiv:1508.01824
# Specifically these are propagated spectra for different cross sections and photon fields
# **Note:** This notebook contains little documentation, for details see
# `examples/Create_Kernel.ipynb` and `examples/Propagate_single_spectrum.ipynb`

# %% [markdown]
# # Setup and save prince_run objects

# %% [markdown]
# Setup and save Kernels for different cross sections
# Analogous to `examples/Create_Kernel.ipynb`

# %%
# %%time
pf = photonfields.CombinedPhotonField(
                [photonfields.CMBPhotonSpectrum, 
                 photonfields.CIBGilmore2D])
cs = cross_sections.FlukaPhotoNuclear()
prince_run_peanut = core.PriNCeRun(max_mass = 56, photon_field=pf, cross_sections=cs)
# Out:
# PriNCeRun::__init__(): initialising Energy grid
# PhotoNuclearInteractionRate::_init_coupling_mat(): Initiating coupling matrix in (CSR) format
# CPU times: user 2min 55s, sys: 27.4 s, total: 3min 22s
# Wall time: 16.8 s

# %% [markdown]
# # Different EBL Models

# %%
from prince_cr.cr_sources import RigdityCutoffSource

# %%
pf_gilmore = photonfields.CombinedPhotonField(
    [photonfields.CMBPhotonSpectrum,photonfields.CIBGilmore2D])

pf_dominguez = photonfields.CombinedPhotonField(
    [photonfields.CMBPhotonSpectrum,photonfields.CIBDominguez2D])

pf_inoue = photonfields.CombinedPhotonField(
    [photonfields.CMBPhotonSpectrum,photonfields.CIBInoue2D])

pf_franc = photonfields.CombinedPhotonField(
    [photonfields.CMBPhotonSpectrum,photonfields.CIBFranceschini2D])

# %%
fig, (ax1) = plt.subplots(1, figsize = (6,4))

eplot = np.logspace(-18, -7, 300)

plt.loglog(eplot, eplot * pf_gilmore.get_photon_density(eplot, 0.), label = 'Franc.')
plt.loglog(eplot, eplot * pf_dominguez.get_photon_density(eplot, 0.), label = 'Inoue.')
plt.loglog(eplot, eplot * pf_inoue.get_photon_density(eplot, 0.), label = 'Gilmore')
plt.loglog(eplot, eplot * pf_franc.get_photon_density(eplot, 0.), label = 'Dominguez')

plt.gca().set_prop_cycle(None)
plt.loglog(eplot, eplot * pf_gilmore.get_photon_density(eplot, 1.), ls = 'dashed')
plt.loglog(eplot, eplot * pf_dominguez.get_photon_density(eplot, 1.), ls = 'dashed')
plt.loglog(eplot, eplot * pf_inoue.get_photon_density(eplot, 1.), ls = 'dashed')
plt.loglog(eplot, eplot * pf_franc.get_photon_density(eplot, 1.), ls = 'dashed')

plt.gca().set_prop_cycle(None)
plt.loglog(eplot, eplot * pf_gilmore.get_photon_density(eplot, 2.), ls = 'dotted')
plt.loglog(eplot, eplot * pf_dominguez.get_photon_density(eplot, 2.), ls = 'dotted')
plt.loglog(eplot, eplot * pf_inoue.get_photon_density(eplot, 2.), ls = 'dotted')
plt.loglog(eplot, eplot * pf_franc.get_photon_density(eplot, 2.), ls = 'dotted')

plt.xlim(1e-14,1e-7)
plt.ylim(1e-6,1e3)

plt.title('photon densities @ $z = 0, 1, 2$')
plt.xlabel('energy [GeV]')
plt.ylabel(r'energy $ \times $ photon density [cm$^{-3}$]')
plt.legend()

plt.tight_layout()

# %% [markdown]
# ### Hard iron

# %%
from prince_cr.solvers import UHECRPropagationSolverETD2

# %%
prince_run = prince_run_peanut

# %%
source_hard_iron = RigdityCutoffSource(prince_run, params={1000260560:(1.0, 5e9,  1.0)}, norm=1e-87)
source_soft_iron = RigdityCutoffSource(prince_run, params={1000260560:(2.0, 1e11, 1.0)}, norm=1e-87)
source_hard_nitro = RigdityCutoffSource(prince_run, params={1000070140:(1.0, 5e9,  1.0)}, norm=1e-87)
source_soft_nitro = RigdityCutoffSource(prince_run, params={1000070140:(2.0, 1e11, 1.0)}, norm=1e-87)

# %%
prince_run.set_photon_field(pf_gilmore)

solver_gilmore = UHECRPropagationSolverETD2(initial_z=1., final_z = 0.,prince_run=prince_run,
                                   enable_pairprod_losses = True, enable_adiabatic_losses = True,
                                   enable_injection_jacobian = True, enable_partial_diff_jacobian=True)
solver_gilmore.add_source_class(source_hard_iron)
solver_gilmore.solve(dz=1e-2,verbose=False,progressbar=True)

# %%
prince_run.set_photon_field(pf_dominguez)

solver_dominguez = UHECRPropagationSolverETD2(initial_z=1., final_z = 0.,prince_run=prince_run,
                                   enable_pairprod_losses = True, enable_adiabatic_losses = True,
                                   enable_injection_jacobian = True, enable_partial_diff_jacobian=True)
solver_dominguez.add_source_class(source_hard_iron)
solver_dominguez.solve(dz=1e-2,verbose=False,progressbar=True)

# %%
prince_run.set_photon_field(pf_franc)

solver_franc = UHECRPropagationSolverETD2(initial_z=1., final_z = 0.,prince_run=prince_run,
                                   enable_pairprod_losses = True, enable_adiabatic_losses = True,
                                   enable_injection_jacobian = True, enable_partial_diff_jacobian=True)
solver_franc.add_source_class(source_hard_iron)
solver_franc.solve(dz=1e-2,verbose=False,progressbar=True)

# %%
prince_run.set_photon_field(pf_inoue)

solver_inoue = UHECRPropagationSolverETD2(initial_z=1., final_z = 0.,prince_run=prince_run,
                                   enable_pairprod_losses = True, enable_adiabatic_losses = True,
                                   enable_injection_jacobian = True, enable_partial_diff_jacobian=True)
solver_inoue.add_source_class(source_hard_iron)
solver_inoue.solve(dz=1e-2,verbose=False,progressbar=True)

# %%
import matplotlib.pyplot as plt

pdgid2sref = solver_gilmore.spec_man.pdgid2sref
Z = lambda el: pdgid2sref[el].Z if (el >= 1000000000 or el in (2212, 2112)) else 0

# normalize
result = solver_gilmore.res
energy, spectrum = result.get_solution_group('CR')
norm = 6e37/np.max(spectrum[(1e10 < energy) & (energy< 1e11)])
alpha = .6

# plot results
for result, ls in zip([solver_gilmore.res,solver_dominguez.res],['solid','dashed']):
    
    for group, color, label in zip([(Z,1,1),(Z,2,2),(Z,3,10),(Z,11,18),(Z,19,26),'CR'],
                                 ['blue','grey','green','magenta','red','black'],
                                 ['Z=1','Z=2','Z=3-8','Z=11-18','Z=19-26','total']):    
        energy, spectrum = result.get_solution_group(group)
        l = plt.plot(np.log10(1e9*energy), norm* spectrum, ls=ls, lw=2., alpha = alpha, label=label, c=color)

#custom legend
ax = plt.gca()
handles, labels = ax.get_legend_handles_labels()
display = (0,1,2,3,4)

#Create custom artists
legend_gilmore = plt.Line2D((0,1),(0,0), color='k', linestyle='solid')
legend_dominguez = plt.Line2D((0,1),(0,0), color='k', linestyle='dashed')

leg2 =  ax.legend([handle for i,handle in enumerate(handles) if i in display],
           [label for i,label in enumerate(labels) if i in display],
                  ncol = 1, loc = 'lower left', fontsize = 'small')
ax.legend([legend_gilmore,legend_dominguez],['Gilmore EBL', 'Dominguez EBL'], 
          frameon=False, fontsize = 'small')
ax.add_artist(leg2)

plt.semilogy()
plt.tick_params(axis='both',top=True,right=True,which='both')
plt.xlim(17.5,20.5)
plt.ylim(1e35,1e38)
# plt.grid()
plt.ylabel('E$^3$ J (arbitrary units)', fontsize = 'large')
plt.xlabel('log$_{10}$ (E/eV)', fontsize = 'large')
plt.title('Hard Iron injection, different EBL models')
plt.tight_layout()

# %% [markdown]
# ### Soft iron

# %%
prince_run.set_photon_field(pf_gilmore)

solver_gilmore = UHECRPropagationSolverETD2(initial_z=1., final_z = 0.,prince_run=prince_run,
                                   enable_pairprod_losses = True, enable_adiabatic_losses = True,
                                   enable_injection_jacobian = True, enable_partial_diff_jacobian=True)
solver_gilmore.add_source_class(source_soft_iron)
solver_gilmore.solve(dz=1e-2,verbose=False)

# %%
prince_run.set_photon_field(pf_dominguez)

solver_dominguez = UHECRPropagationSolverETD2(initial_z=1., final_z = 0.,prince_run=prince_run,
                                   enable_pairprod_losses = True, enable_adiabatic_losses = True,
                                   enable_injection_jacobian = True, enable_partial_diff_jacobian=True)
solver_dominguez.add_source_class(source_soft_iron)
solver_dominguez.solve(dz=1e-2,verbose=False,progressbar=True)

# %%
prince_run.set_photon_field(pf_franc)

solver_franc = UHECRPropagationSolverETD2(initial_z=1., final_z = 0.,prince_run=prince_run,
                                   enable_pairprod_losses = True, enable_adiabatic_losses = True,
                                   enable_injection_jacobian = True, enable_partial_diff_jacobian=True)
solver_franc.add_source_class(source_soft_iron)
solver_franc.solve(dz=1e-2,verbose=False,progressbar=True)

# %%
prince_run.set_photon_field(pf_inoue)

solver_inoue = UHECRPropagationSolverETD2(initial_z=1., final_z = 0.,prince_run=prince_run,
                                   enable_pairprod_losses = True, enable_adiabatic_losses = True,
                                   enable_injection_jacobian = True, enable_partial_diff_jacobian=True)
solver_inoue.add_source_class(source_soft_iron)
solver_inoue.solve(dz=1e-2,verbose=False,progressbar=True)

# %%
import matplotlib.pyplot as plt

pdgid2sref = solver_gilmore.spec_man.pdgid2sref
Z = lambda el: pdgid2sref[el].Z if (el >= 1000000000 or el in (2212, 2112)) else 0

# normalize
result = solver_gilmore.res
energy, spectrum = result.get_solution_group('CR')
norm = 6e37/np.max(spectrum[(1e10 < energy) & (energy< 1e11)])
alpha = .6

# plot results
for result, ls in zip([solver_gilmore.res,solver_dominguez.res],['solid','dashed']):
    
    for group, color, label in zip([(Z,1,1),(Z,2,2),(Z,3,10),(Z,11,18),(Z,19,26),'CR'],
                                 ['blue','grey','green','magenta','red','black'],
                                 ['Z=1','Z=2','Z=3-8','Z=11-18','Z=19-26','total']):    
        energy, spectrum = result.get_solution_group(group)
        l = plt.plot(np.log10(1e9*energy), norm* spectrum, ls=ls, lw=2., alpha = alpha, label=label, c=color)

#custom legend
ax = plt.gca()
handles, labels = ax.get_legend_handles_labels()
display = (0,1,2,3,4)

#Create custom artists
legend_gilmore = plt.Line2D((0,1),(0,0), color='k', linestyle='solid')
legend_dominguez = plt.Line2D((0,1),(0,0), color='k', linestyle='dashed')

leg2 =  ax.legend([handle for i,handle in enumerate(handles) if i in display],
           [label for i,label in enumerate(labels) if i in display],
                  ncol = 1, loc = 'lower left', fontsize = 'small')
ax.legend([legend_gilmore,legend_dominguez],['Gilmore EBL', 'Dominguez EBL'], 
          frameon=False, fontsize = 'small')
ax.add_artist(leg2)

plt.semilogy()
# plt.legend(ncol=1, loc='upper left')
plt.tick_params(axis='both',top=True,right=True,which='both')
plt.xlim(17.5,20.5)
plt.ylim(1e35,1e38)
# plt.grid()
plt.ylabel('E$^3$ J (arbitrary units)', fontsize = 'large')
plt.xlabel('log$_{10}$ (E/eV)', fontsize = 'large')
plt.title('Soft Iron injection, different EBL models')
plt.tight_layout()
